# %% [markdown]
# ---
#
# ### ✅ **1. Subjects API**
# | Action        | HTTP Method | URL Path                     |
# |--------------|------------|------------------------------|
# | List all subjects  | `GET`       | `/subjects/` |
# | Retrieve a subject | `GET`       | `/subjects/{id}/` |
# | Create a subject   | `POST`      | `/subjects/` |
# | Update a subject (full) | `PUT`  | `/subjects/{id}/` |
# | Update a subject (partial) | `PATCH` | `/subjects/{id}/` |
# | Delete a subject   | `DELETE`    | `/subjects/{id}/` |
#
# ---
#
# ### ✅ **2. Categories API**
# | Action        | HTTP Method | URL Path                     |
# |--------------|------------|------------------------------|
# | List all categories  | `GET`       | `/categories/` |
# | Retrieve a category  | `GET`       | `/categories/{id}/` |
# | Create a category    | `POST`      | `/categories/` |
# | Update a category (full) | `PUT`  | `/categories/{id}/` |
# | Update a category (partial) | `PATCH` | `/categories/{id}/` |
# | Delete a category    | `DELETE`    | `/categories/{id}/` |
#
# ---
#
# ### ✅ **3. Quizzes API**
# | Action        | HTTP Method | URL Path                     |
# |--------------|------------|------------------------------|
# | List all quizzes  | `GET`       | `/quizzes/` |
# | Retrieve a quiz  | `GET`       | `/quizzes/{id}/` |
# | Create a quiz    | `POST`      | `/quizzes/` |
# | Update a quiz (full) | `PUT`  | `/quizzes/{id}/` |
# | Update a quiz (partial) | `PATCH` | `/quizzes/{id}/` |
# | Delete a quiz    | `DELETE`    | `/quizzes/{id}/` |
#
# ---
#
# ### ✅ **4. Questions API**
# | Action        | HTTP Method | URL Path                     |
# |--------------|------------|------------------------------|
# | List all questions  | `GET`       | `/questions/` |
# | Retrieve a question | `GET`       | `/questions/{id}/` |
# | Create a question   | `POST`      | `/questions/` |
# | Update a question (full) | `PUT`  | `/questions/{id}/` |
# | Update a question (partial) | `PATCH` | `/questions/{id}/` |
# | Delete a question   | `DELETE`    | `/questions/{id}/` |
# | List questions by quiz | `GET` | `/questions/?quiz_pk={quiz_id}` |
#
# ---
#
# ### 🚀 **Key Notes:**
# 1. `GET /questions/?quiz_pk=1` → Filters questions for **Quiz ID 1**.
# 2. `PATCH` is used for **partial updates**, whereas `PUT` replaces the entire object.
# 3. All CRUD operations are automatically handled by `ModelViewSet`.
